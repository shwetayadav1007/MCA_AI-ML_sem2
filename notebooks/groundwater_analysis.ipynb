# %% [markdown]
# # Groundwater Analysis
#
# This notebook contains exploratory analysis, visualization, and model experimentation for groundwater prediction.

# %%
import pandas as pd
df = pd.read_csv('../data/raw/groundwater.csv')
df.head()
